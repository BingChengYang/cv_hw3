# %%
from detectron2.engine import DefaultPredictor
from detectron2.data import MetadataCatalog
from detectron2.config import get_cfg
from detectron2.utils.visualizer import ColorMode, Visualizer
from detectron2 import model_zoo
from detectron2.data.datasets import register_coco_instances
import random
import cv2
import numpy as np
import os
from detectron2.data import MetadataCatalog, DatasetCatalog
from os import listdir
from os.path import isfile, join
import json

# %%
register_coco_instances("tiny_voc_test", {}, "./data/test.json ", "./data/test_images/test_images")

# %%
cfg = get_cfg()
cfg.merge_from_file(
    "./configs/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"
)
cfg.DATASETS.TEST = ("tiny_voc_test",)
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5# Threshold
cfg.MODEL.WEIGHTS = "./output/model_final.pth"
cfg.MODEL.DEVICE = "cuda" # cpu or cuda
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 20 # 3 classes (data, fig, hazelnut)

# %%
predictor = DefaultPredictor(cfg)
dataset_dicts = DatasetCatalog.get("tiny_voc_test")
cnt = 0
for d in dataset_dicts:    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    print(outputs)
    v = Visualizer(im[:, :, ::-1],
                   metadata=MetadataCatalog.get("tiny_voc_test"), 
                   scale=0.8, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2.imshow('images', v.get_image()[:, :, ::-1])
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    cnt += 1
    if cnt > 5:
        break
# Out:
# c:\users\bingcheng\detectron2-windows\detectron2\layers\wrappers.py:226: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:882.)
#   return x.nonzero().unbind(1)
# {'instances': Instances(num_instances=2, image_height=230, image_width=500, fields=[pred_boxes: Boxes(tensor([[ 73.2602,  80.7937, 439.7700, 180.9244],
#         [  5.3683,  46.0687, 328.8905, 188.3053]], device='cuda:0')), scores: tensor([0.8701, 0.6226], device='cuda:0'), pred_classes: tensor([18, 18], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
# {'instances': Instances(num_instances=12, image_height=375, image_width=500, fields=[pred_boxes: Boxes(tensor([[2.2650e+01, 1.7543e+01, 5.6339e+01, 1.2529e+02],
#         [3.5307e+02, 9.6659e+01, 4.0937e+02, 1.9006e+02],
#         [3.3431e+02, 1.1476e+02, 4.4827e+02, 1.7722e+02],
#         [4.9041e+00, 0.0000e+00, 5.1477e+01, 1.9317e+02],
#         [3.6322e+02, 1.0137e+02, 3.8666e+02, 1.8101e+02],
#         [4.7557e+01, 8.4488e+01, 1.9662e+02, 3.4783e+02],
#         [3.5353e+02, 1.0882e+02, 3.7106e+02, 1.7284e+02],
#         [4.0121e+02, 2.2701e+02, 5.0000e+02, 3.6275e+02],
#         [1.8548e-02, 1.6971e+02, 2.8957e+02, 3.0796e+02],
#         [3.5126e+02, 1.3190e+02, 4.8525e+02, 2.2670e+02],
#         [3.1848e+01, 1.7974e+02, 3.4871e+02, 3.6792e+02],
#         [2.1887e+02, 1.3496e+02, 3.8540e+02, 3.4618e+02]], device='cuda:0')), scores: tensor([0.8894, 0.8626, 0.7993, 0.7552, 0.6819, 0.6764, 0.6219, 0.6137, 0.6079,
#         0.5775, 0.5653, 0.5357], device='cuda:0'), pred_classes: tensor([14, 19, 19, 14, 19, 14, 19, 14, 17,  8, 17, 14], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
# {'instances': Instances(num_instances=9, image_height=375, image_width=500, fields=[pred_boxes: Boxes(tensor([[118.0488,  78.8067, 330.4144, 269.0309],
#         [ 78.2157, 122.4922, 302.4935, 352.5866],
#         [122.0071, 110.8427, 418.5501, 316.7553],
#         [ 71.2838, 191.3560, 422.1771, 362.6310],
#         [ 47.7561,  61.9871, 337.9602, 204.6582],
#         [234.9186, 113.9176, 345.5807, 291.0272],
#         [114.3818,  84.8052, 247.2637, 201.8173],
#         [194.1559,  45.8201, 369.7792, 268.6328],
#         [253.0734,  34.1225, 500.0000, 310.7083]], device='cuda:0')), scores: tensor([0.9663, 0.9516, 0.9284, 0.7323, 0.7105, 0.6531, 0.6155, 0.5225, 0.5198],
#        device='cuda:0'), pred_classes: tensor([11, 11, 11, 11, 11, 11, 11, 11, 17], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
# {'instances': Instances(num_instances=2, image_height=500, image_width=500, fields=[pred_boxes: Boxes(tensor([[242.3549, 260.0747, 304.2195, 323.6801],
#         [192.0928, 280.0853, 236.1140, 343.3006]], device='cuda:0')), scores: tensor([0.7933, 0.6105], device='cuda:0'), pred_classes: tensor([16, 16], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
# {'instances': Instances(num_instances=6, image_height=374, image_width=500, fields=[pred_boxes: Boxes(tensor([[ 46.7810,  94.6845, 327.5189, 225.2427],
#         [ 46.2447,  70.4465, 437.2741, 276.7318],
#         [190.8419,  73.2531, 484.6118, 329.8327],
#         [106.6530,  45.5595, 490.5369, 262.1545],
#         [ 48.1549,  85.8178, 189.4629, 202.8351],
#         [327.8409, 110.9530, 486.7279, 339.7498]], device='cuda:0')), scores: tensor([0.8128, 0.7380, 0.7185, 0.6442, 0.6378, 0.5100], device='cuda:0'), pred_classes: tensor([3, 3, 3, 0, 3, 3], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}
# {'instances': Instances(num_instances=7, image_height=375, image_width=500, fields=[pred_boxes: Boxes(tensor([[220.5445, 174.6340, 304.7749, 351.4775],
#         [162.9754, 183.3550, 355.1523, 358.8392],
#         [158.2935, 197.0332, 244.1172, 359.0199],
#         [217.4253, 249.2306, 456.3762, 375.0000],
#         [197.2563, 173.2971, 328.6292, 290.3645],
#         [220.1129, 164.1633, 295.7363, 239.6992],
#         [141.9274, 233.0037, 308.8536, 347.3452]], device='cuda:0')), scores: tensor([0.9805, 0.9426, 0.8151, 0.8038, 0.7558, 0.6374, 0.6040],
#        device='cuda:0'), pred_classes: tensor([14, 14, 14, 13, 14, 14, 14], device='cuda:0'), pred_masks: tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]]], device='cuda:0')])}

# %%
import numpy as np
from itertools import groupby
from pycocotools import mask as maskutil

def binary_mask_to_rle(binary_mask):
    rle = {'counts': [], 'size': list(binary_mask.shape)}
    counts = rle.get('counts')
    for i, (value, elements) in enumerate(groupby(binary_mask.ravel(order='F'))):
        if i == 0 and value == 1:
            counts.append(0)
        counts.append(len(list(elements)))
    compressed_rle = maskutil.frPyObjects(rle, rle.get('size')[0], rle.get('size')[1])
    compressed_rle['counts'] = str(compressed_rle['counts'], encoding='utf-8')
    return compressed_rle

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

cocoGt = COCO("./data/test.json")
cnt = 0
submit = []
for imgid in cocoGt.imgs:
#     print(d)
    im = cv2.imread("./data/test_images/test_images/" + cocoGt.loadImgs(ids=imgid)[0]['file_name'])
    outputs = predictor(im)
#       
#     print(outputs)
    score = outputs['instances'].scores
    score = (score.cpu().numpy()).tolist()
    label = outputs['instances'].pred_classes
    label = (label.cpu().numpy()).tolist()
    mask = outputs['instances'].pred_masks
    mask = (mask.cpu().numpy())
    n_instances = len(score)
#     print(len(score))
    if len(label) > 0:
        for i in range(n_instances):
            pred = {}
            pred['image_id'] = imgid # this imgid must be same as the key of test.json
            pred['category_id'] = (int(label[i]) + 1)
#             print(len(mask[i]))
            
            pred['segmentation'] = binary_mask_to_rle(mask[i]) # save binary mask to RLE, e.g. 512x512 -> rle
            pred['score'] = float(score[i])
            submit.append(pred)
#             cnt += 1
#             if cnt > 0:
#                 break
#         if cnt > 0:
#             break
# print(submit)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cb977b0d51eb> in <module>
#       8 #     print(d)
#       9     im = cv2.imread("./data/test_images/test_images/" + cocoGt.loadImgs(ids=imgid)[0]['file_name'])
# ---> 10     outputs = predictor(im)
#      11 #
#      12 #     print(outputs)
#
# NameError: name 'predictor' is not defined

# %%
with open("0756545.json", "w") as f:
    json.dump(submit, f)
